# %%
import pandas as pd 
df=pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\data analyst\assignment.py\train.csv')

# %%
df.isna().sum() # its isnull is used to count the null value count/ sum of null value
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.drop(columns=["Row ID","Country"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   str
#  1   Order Date     9800 non-null   str
#  2   Ship Date      9800 non-null   str
#  3   Ship Mode      9800 non-null   str
#  4   Customer ID    9800 non-null   str
#  5   Customer Name  9800 non-null   str
#  6   Segment        9800 non-null   str
#  7   City           9800 non-null   str
#  8   State          9800 non-null   str
#  9   Postal Code    9789 non-null   float64
#  10  Region         9800 non-null   str
#  11  Product ID     9800 non-null   str
#  12  Category       9800 non-null   str
#  13  Sub-Category   9800 non-null   str
#  14  Product Name   9800 non-null   str
#  15  Sales          9800 non-null   float64
# dtypes: float64(2), str(14)
# memory usage: 2.8 MB

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"] , dayfirst=True)
df["Ship Date"]=pd.to_datetime(df["Ship Date"] , dayfirst=True)
print(df[["Order Date", "Ship Date"]].head())
# Out:
#   Order Date  Ship Date
# 0 2017-11-08 2017-11-11
# 1 2017-11-08 2017-11-11
# 2 2017-06-12 2017-06-16
# 3 2016-10-11 2016-10-18
# 4 2016-10-11 2016-10-18

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   str
#  1   Order Date     9800 non-null   datetime64[us]
#  2   Ship Date      9800 non-null   datetime64[us]
#  3   Ship Mode      9800 non-null   str
#  4   Customer ID    9800 non-null   str
#  5   Customer Name  9800 non-null   str
#  6   Segment        9800 non-null   str
#  7   City           9800 non-null   str
#  8   State          9800 non-null   str
#  9   Postal Code    9789 non-null   float64
#  10  Region         9800 non-null   str
#  11  Product ID     9800 non-null   str
#  12  Category       9800 non-null   str
#  13  Sub-Category   9800 non-null   str
#  14  Product Name   9800 non-null   str
#  15  Sales          9800 non-null   float64
# dtypes: datetime64[us](2), float64(2), str(12)
# memory usage: 2.6 MB

# %%
df["Postal Code"]=df['Postal Code'].fillna(0).astype(int).astype(str).str.zfill(5)

# %%
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df.nunique()
# Out:
# Order ID         4922
# Order Date       1230
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# City              529
# State              49
# Postal Code       627
# Region              4
# Product ID       1861
# Category            3
# Sub-Category       17
# Product Name     1849
# Sales            5757
# dtype: int64

# %%
df['Ship_Days'] = (df['Ship Date'] - df['Order Date']).dt.days
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Postal Code Region  \
# 0      Claire Gute   Consumer        Henderson    Kentucky       42420  South
# 1      Claire Gute   Consumer        Henderson    Kentucky       42420  South
# 2  Darrin Van Huff  Corporate      Los Angeles  California       90036   West
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida       33311  South
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida       33311  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df['Order_Year'] = df['Order Date'].dt.year
df['Order_Month'] = df['Order Date'].dt.month

# %%
df.head(15)
# Out:
#           Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1   CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2   CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3   US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4   US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 5   CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 6   CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 7   CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 8   CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 9   CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 10  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 11  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 12  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   str
#  1   Order Date     9800 non-null   datetime64[us]
#  2   Ship Date      9800 non-null   datetime64[us]
#  3   Ship Mode      9800 non-null   str
#  4   Customer ID    9800 non-null   str
#  5   Customer Name  9800 non-null   str
#  6   Segment        9800 non-null   str
#  7   City           9800 non-null   str
#  8   State          9800 non-null   str
#  9   Postal Code    9800 non-null   str
#  10  Region         9800 non-null   str
#  11  Product ID     9800 non-null   str
#  12  Category       9800 non-null   str
#  13  Sub-Category   9800 non-null   str
#  14  Product Name   9800 non-null   str
#  15  Sales          9800 non-null   float64
#  16  Ship_Days      9800 non-null   int64
#  17  Order_Year     9800 non-null   int32
# ...

# %%
import os
import mysql.connector
import pandas as pd
from dotenv import load_dotenv


load_dotenv()


try:
    db = mysql.connector.connect(
        host=os.getenv("DB_HOST"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        database=os.getenv("DB_NAME")
    )
    print("Successfully connected to the database!")
    
 
    query = "SELECT * FROM sales_data"
    df = pd.read_sql(query, db)
    
   
    print(df.head())

except mysql.connector.Error as err:
    print(f"Error: {err}")

finally:
    if 'db' in locals() and db.is_connected():
        db.close()
        print("MySQL connection is closed.")
# Out:
# Successfully connected to the database!
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5304\1560104649.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, db)
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Postal Code Region  \
# 0      Claire Gute   Consumer        Henderson    Kentucky       42420  South
# ...
